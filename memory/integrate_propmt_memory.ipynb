# %%
from langchain.chat_models import ChatOpenAI
from langchain.memory import ConversationSummaryBufferMemory
from langchain.schema.runnable import RunnablePassthrough
from langchain.prompts import ChatPromptTemplate, MessagesPlaceholder

chat_model = ChatOpenAI(temperature=0.1)

memory = ConversationSummaryBufferMemory(
    llm=chat_model, 
    max_token_limit=180,
    return_messages=True,
    memory_key="question_history"
)

prompt = ChatPromptTemplate.from_messages([
    ("system", "당신은 채팅 AI 입니다. 미국 뉴욕에 살고 있다고 가정하고 채팅해주세요"),
    MessagesPlaceholder(variable_name="question_history"),
    ("human", "{question}")
])

def load_memory(input):
    print(input)
    return memory.load_memory_variables({})["question_history"]


chain = RunnablePassthrough.assign(question_history=load_memory) | prompt | chat_model

def chain_invoke(q):
    result = chain.invoke({
        "question": q
        })
    
    memory.save_context({"input": q}, { "output": result.content})
    print(result)
    


chain_invoke("저는 지민이에요")
chain_invoke("저는 한국에 살고 있어요")
# Out:
# [chain/start] [1:chain:RunnableSequence] Entering Chain run with input:
# {
#   "question": "저는 지민이에요"
# }
# [chain/start] [1:chain:RunnableSequence > 2:chain:RunnableParallel] Entering Chain run with input:
# {
#   "question": "저는 지민이에요"
# }
# [chain/start] [1:chain:RunnableSequence > 2:chain:RunnableParallel > 3:chain:load_memory] Entering Chain run with input:
# {
#   "question": "저는 지민이에요"
# }
# {'question': '저는 지민이에요'}
# [chain/end] [1:chain:RunnableSequence > 2:chain:RunnableParallel > 3:chain:load_memory] s] Exiting Chain run with output:
# {
#   "output": []
# }
# [chain/end] [1:chain:RunnableSequence > 2:chain:RunnableParallel] s] Exiting Chain run with output:
# {
#   "question_history": []
# }
# [chain/start] [1:chain:RunnableSequence > 4:prompt:ChatPromptTemplate] Entering Prompt run with input:
# {
#   "question": "저는 지민이에요",
#   "question_history": []
# }
# [chain/end] [1:chain:RunnableSequence > 4:prompt:ChatPromptTemplate] s] Exiting Prompt run with output:
# {
#   "lc": 1,
#   "type": "constructor",
#   "id": [
#     "langchain",
#     "prompts",
#     "chat",
#     "ChatPromptValue"
#   ],
#   "kwargs": {
#     "messages": [
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "messages",
#           "SystemMessage"
#         ],
#         "kwargs": {
#           "content": "당신은 채팅 AI 입니다. 미국 뉴욕에 살고 있다고 가정하고 채팅해주세요",
#           "additional_kwargs": {}
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "messages",
#           "HumanMessage"
#         ],
#         "kwargs": {
#           "content": "저는 지민이에요",
#           "additional_kwargs": {}
#         }
#       }
#     ]
#   }
# }
# [llm/start] [1:chain:RunnableSequence > 5:llm:ChatOpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "System: 당신은 채팅 AI 입니다. 미국 뉴욕에 살고 있다고 가정하고 채팅해주세요\nHuman: 저는 지민이에요"
#   ]
# }
# [llm/end] [1:chain:RunnableSequence > 5:llm:ChatOpenAI] [1.26s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "안녕 지민이! 반가워요. 뉴욕에서는 무슨 일을 하고 있나요? 무얼 도와드릴까요?",
#         "generation_info": {
#           "finish_reason": "stop"
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "안녕 지민이! 반가워요. 뉴욕에서는 무슨 일을 하고 있나요? 무얼 도와드릴까요?",
#             "additional_kwargs": {}
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {
#       "prompt_tokens": 60,
#       "completion_tokens": 48,
#       "total_tokens": 108
#     },
#     "model_name": "gpt-3.5-turbo",
#     "system_fingerprint": null
#   },
#   "run": null
# }
# [chain/end] [1:chain:RunnableSequence] [1.27s] Exiting Chain run with output:
# [outputs]
# content='안녕 지민이! 반가워요. 뉴욕에서는 무슨 일을 하고 있나요? 무얼 도와드릴까요?'
# [chain/start] [1:chain:RunnableSequence] Entering Chain run with input:
# {
#   "question": "저는 한국에 살고 있어요"
# }
# [chain/start] [1:chain:RunnableSequence > 2:chain:RunnableParallel] Entering Chain run with input:
# {
#   "question": "저는 한국에 살고 있어요"
# }
# [chain/start] [1:chain:RunnableSequence > 2:chain:RunnableParallel > 3:chain:load_memory] Entering Chain run with input:
# {
#   "question": "저는 한국에 살고 있어요"
# }
# {'question': '저는 한국에 살고 있어요'}
# [chain/end] [1:chain:RunnableSequence > 2:chain:RunnableParallel > 3:chain:load_memory] s] Exiting Chain run with output:
# {
#   "output": [
#     {
#       "lc": 1,
#       "type": "constructor",
#       "id": [
#         "langchain",
#         "schema",
#         "messages",
#         "HumanMessage"
#       ],
#       "kwargs": {
#         "content": "저는 지민이에요"
#       }
#     },
#     {
#       "lc": 1,
#       "type": "constructor",
#       "id": [
#         "langchain",
#         "schema",
#         "messages",
#         "AIMessage"
#       ],
#       "kwargs": {
#         "content": "안녕 지민이! 반가워요. 뉴욕에서는 무슨 일을 하고 있나요? 무얼 도와드릴까요?"
#       }
#     }
#   ]
# }
# [chain/end] [1:chain:RunnableSequence > 2:chain:RunnableParallel] s] Exiting Chain run with output:
# [outputs]
# [chain/start] [1:chain:RunnableSequence > 4:prompt:ChatPromptTemplate] Entering Prompt run with input:
# [inputs]
# [chain/end] [1:chain:RunnableSequence > 4:prompt:ChatPromptTemplate] s] Exiting Prompt run with output:
# {
#   "lc": 1,
#   "type": "constructor",
#   "id": [
#     "langchain",
#     "prompts",
#     "chat",
#     "ChatPromptValue"
#   ],
#   "kwargs": {
#     "messages": [
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "messages",
#           "SystemMessage"
#         ],
#         "kwargs": {
#           "content": "당신은 채팅 AI 입니다. 미국 뉴욕에 살고 있다고 가정하고 채팅해주세요",
#           "additional_kwargs": {}
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "messages",
#           "HumanMessage"
#         ],
#         "kwargs": {
#           "content": "저는 지민이에요"
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "messages",
#           "AIMessage"
#         ],
#         "kwargs": {
#           "content": "안녕 지민이! 반가워요. 뉴욕에서는 무슨 일을 하고 있나요? 무얼 도와드릴까요?"
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "messages",
#           "HumanMessage"
#         ],
#         "kwargs": {
#           "content": "저는 한국에 살고 있어요",
#           "additional_kwargs": {}
#         }
#       }
#     ]
#   }
# }
# [llm/start] [1:chain:RunnableSequence > 5:llm:ChatOpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "System: 당신은 채팅 AI 입니다. 미국 뉴욕에 살고 있다고 가정하고 채팅해주세요\nHuman: 저는 지민이에요\nAI: 안녕 지민이! 반가워요. 뉴욕에서는 무슨 일을 하고 있나요? 무얼 도와드릴까요?\nHuman: 저는 한국에 살고 있어요"
#   ]
# }
# [llm/end] [1:chain:RunnableSequence > 5:llm:ChatOpenAI] [2.05s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "알겠어요, 한국에 사는 지민이네요! 한국은 정말 멋진 나라죠. 미국 뉴욕에 대해 궁금한 점이 있거나 이야기를 나누고 싶은 게 있으면 언제든지 말해주세요. 함께 이야기 나누는 걸 즐기고 있어요!",
#         "generation_info": {
#           "finish_reason": "stop"
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "알겠어요, 한국에 사는 지민이네요! 한국은 정말 멋진 나라죠. 미국 뉴욕에 대해 궁금한 점이 있거나 이야기를 나누고 싶은 게 있으면 언제든지 말해주세요. 함께 이야기 나누는 걸 즐기고 있어요!",
#             "additional_kwargs": {}
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {
#       "prompt_tokens": 130,
#       "completion_tokens": 110,
#       "total_tokens": 240
#     },
#     "model_name": "gpt-3.5-turbo",
#     "system_fingerprint": null
#   },
#   "run": null
# }
# [chain/end] [1:chain:RunnableSequence] [2.06s] Exiting Chain run with output:
# [outputs]
# [chain/start] [1:chain:LLMChain] Entering Chain run with input:
# {
#   "summary": "",
#   "new_lines": "Human: 저는 지민이에요\nAI: 안녕 지민이! 반가워요. 뉴욕에서는 무슨 일을 하고 있나요? 무얼 도와드릴까요?"
# }
# [llm/start] [1:chain:LLMChain > 2:llm:ChatOpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: Progressively summarize the lines of conversation provided, adding onto the previous summary returning a new summary.\n\nEXAMPLE\nCurrent summary:\nThe human asks what the AI thinks of artificial intelligence. The AI thinks artificial intelligence is a force for good.\n\nNew lines of conversation:\nHuman: Why do you think artificial intelligence is a force for good?\nAI: Because artificial intelligence will help humans reach their full potential.\n\nNew summary:\nThe human asks what the AI thinks of artificial intelligence. The AI thinks artificial intelligence is a force for good because it will help humans reach their full potential.\nEND OF EXAMPLE\n\nCurrent summary:\n\n\nNew lines of conversation:\nHuman: 저는 지민이에요\nAI: 안녕 지민이! 반가워요. 뉴욕에서는 무슨 일을 하고 있나요? 무얼 도와드릴까요?\n\nNew summary:"
#   ]
# }
# [llm/end] [1:chain:LLMChain > 2:llm:ChatOpenAI] [1.00s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "The human introduces themselves as Jimin. The AI greets Jimin and asks what they do in New York and how it can help.",
#         "generation_info": {
#           "finish_reason": "stop"
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "The human introduces themselves as Jimin. The AI greets Jimin and asks what they do in New York and how it can help.",
#             "additional_kwargs": {}
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {
#       "prompt_tokens": 195,
#       "completion_tokens": 28,
#       "total_tokens": 223
#     },
#     "model_name": "gpt-3.5-turbo",
#     "system_fingerprint": null
#   },
#   "run": null
# }
# [chain/end] [1:chain:LLMChain] [1.00s] Exiting Chain run with output:
# {
#   "text": "The human introduces themselves as Jimin. The AI greets Jimin and asks what they do in New York and how it can help."
# }
# content='알겠어요, 한국에 사는 지민이네요! 한국은 정말 멋진 나라죠. 미국 뉴욕에 대해 궁금한 점이 있거나 이야기를 나누고 싶은 게 있으면 언제든지 말해주세요. 함께 이야기 나누는 걸 즐기고 있어요!'

# %%
chain.predict(question="저는 한국에 살고 있어요")

# %%
chain.predict(question="저는 어디에 있나요?")

# %%
memory.load_memory_variables({})
