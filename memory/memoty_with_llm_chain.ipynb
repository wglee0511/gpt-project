# %%
from langchain.chat_models import ChatOpenAI
from langchain.memory import ConversationSummaryBufferMemory
from langchain.chains import LLMChain
from langchain.prompts import PromptTemplate

chat_model = ChatOpenAI(temperature=0.1)
template = """
    당신은 채팅 AI 입니다.
    {question_history}
    
    Human: {question}
    You:
"""
prompt = PromptTemplate.from_template(template)
memory = ConversationSummaryBufferMemory(
    llm=chat_model, 
    max_token_limit=180,
    return_messages=True,
    memory_key="question_history"
)

chain = LLMChain(
    llm=chat_model,
    memory=memory,
    prompt=prompt
)

chain.predict(question="안녕하세요")
# Out:
# [chain/start] [1:chain:LLMChain] Entering Chain run with input:
# {
#   "question": "안녕하세요",
#   "question_history": []
# }
# [llm/start] [1:chain:LLMChain > 2:llm:ChatOpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: \n    당신은 채팅 AI 입니다.\n    []\n    \n    Human: 안녕하세요\n    You:"
#   ]
# }
# [llm/end] [1:chain:LLMChain > 2:llm:ChatOpenAI] s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "안녕하세요! 무엇을 도와드릴까요?",
#         "generation_info": {
#           "finish_reason": "stop"
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "안녕하세요! 무엇을 도와드릴까요?",
#             "additional_kwargs": {}
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {
#       "prompt_tokens": 36,
#       "completion_tokens": 21,
#       "total_tokens": 57
#     },
#     "model_name": "gpt-3.5-turbo",
#     "system_fingerprint": null
#   },
#   "run": null
# }
# [chain/end] [1:chain:LLMChain] s] Exiting Chain run with output:
# {
#   "text": "안녕하세요! 무엇을 도와드릴까요?"
# }
# '안녕하세요! 무엇을 도와드릴까요?'

# %%
chain.predict(question="저는 한국에 살고 있어요")
# Out:
# [chain/start] [1:chain:LLMChain] Entering Chain run with input:
# [inputs]
# [llm/start] [1:chain:LLMChain > 2:llm:ChatOpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: \n    당신은 채팅 AI 입니다.\n    [SystemMessage(content='The human greets the AI in Korean and asks where they are. The AI responds in Korean, stating that they are currently conversing online and asks how it can help.')]\n    \n    Human: 저는 한국에 살고 있어요\n    You:"
#   ]
# }
# [llm/end] [1:chain:LLMChain > 2:llm:ChatOpenAI] s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "안녕하세요! 온라인에서 대화 중이에요. 무엇을 도와드릴까요?",
#         "generation_info": {
#           "finish_reason": "stop"
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "안녕하세요! 온라인에서 대화 중이에요. 무엇을 도와드릴까요?",
#             "additional_kwargs": {}
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {
#       "prompt_tokens": 86,
#       "completion_tokens": 33,
#       "total_tokens": 119
#     },
#     "model_name": "gpt-3.5-turbo",
#     "system_fingerprint": null
#   },
#   "run": null
# }
# [chain/end] [1:chain:LLMChain] s] Exiting Chain run with output:
# {
#   "text": "안녕하세요! 온라인에서 대화 중이에요. 무엇을 도와드릴까요?"
# }
# [chain/start] [1:chain:LLMChain] Entering Chain run with input:
# {
#   "summary": "The human greets the AI in Korean and asks where they are. The AI responds in Korean, stating that they are currently conversing online and asks how it can help.",
#   "new_lines": "Human: 저는 한국에 살고 있어요\nAI: 안녕하세요! 온라인에서 대화 중이에요. 무엇을 도와드릴까요?"
# }
# [llm/start] [1:chain:LLMChain > 2:llm:ChatOpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: Progressively summarize the lines of conversation provided, adding onto the previous summary returning a new summary.\n\nEXAMPLE\nCurrent summary:\nThe human asks what the AI thinks of artificial intelligence. The AI thinks artificial intelligence is a force for good.\n\nNew lines of conversation:\nHuman: Why do you think artificial intelligence is a force for good?\nAI: Because artificial intelligence will help humans reach their full potential.\n\nNew summary:\nThe human asks what the AI thinks of artificial intelligence. The AI thinks artificial intelligence is a force for good because it will help humans reach their full potential.\nEND OF EXAMPLE\n\nCurrent summary:\nThe human greets the AI in Korean and asks where they are. The AI responds in Korean, stating that they are currently conversing online and asks how it can help.\n\nNew lines of conversation:\nHuman: 저는 한국에 살고 있어요\nAI: 안녕하세요! 온라인에서 대화 중이에요. 무엇을 도와드릴까요?\n\nNew summary:"
#   ]
# }
# [llm/end] [1:chain:LLMChain > 2:llm:ChatOpenAI] [1.15s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "The human greets the AI in Korean and mentions living in Korea. The AI responds in Korean, stating they are currently conversing online and asks how they can help.",
#         "generation_info": {
#           "finish_reason": "stop"
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "The human greets the AI in Korean and mentions living in Korea. The AI responds in Korean, stating they are currently conversing online and asks how they can help.",
#             "additional_kwargs": {}
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {
#       "prompt_tokens": 220,
#       "completion_tokens": 34,
#       "total_tokens": 254
#     },
#     "model_name": "gpt-3.5-turbo",
#     "system_fingerprint": null
#   },
#   "run": null
# }
# [chain/end] [1:chain:LLMChain] [1.15s] Exiting Chain run with output:
# {
#   "text": "The human greets the AI in Korean and mentions living in Korea. The AI responds in Korean, stating they are currently conversing online and asks how they can help."
# }
# '안녕하세요! 온라인에서 대화 중이에요. 무엇을 도와드릴까요?'

# %%
chain.predict(question="저는 어디에 있나요?")
# Out:
# [chain/start] [1:chain:LLMChain] Entering Chain run with input:
# [inputs]
# [llm/start] [1:chain:LLMChain > 2:llm:ChatOpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: \n    당신은 채팅 AI 입니다.\n    [SystemMessage(content='The human greets the AI in Korean. The AI responds in Korean and asks how it can help.')]\n    \n    Human: 저는 어디에 있나요?\n    You:"
#   ]
# }
# [llm/end] [1:chain:LLMChain > 2:llm:ChatOpenAI] s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "AI: 당신은 현재 온라인 상에서 저와 대화하고 있습니다. 어떻게 도와드릴까요?",
#         "generation_info": {
#           "finish_reason": "stop"
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "AI: 당신은 현재 온라인 상에서 저와 대화하고 있습니다. 어떻게 도와드릴까요?",
#             "additional_kwargs": {}
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": null,
#   "run": null
# }
# [chain/end] [1:chain:LLMChain] s] Exiting Chain run with output:
# {
#   "text": "AI: 당신은 현재 온라인 상에서 저와 대화하고 있습니다. 어떻게 도와드릴까요?"
# }
# [chain/start] [1:chain:LLMChain] Entering Chain run with input:
# {
#   "summary": "The human greets the AI in Korean. The AI responds in Korean and asks how it can help.",
#   "new_lines": "Human: 저는 어디에 있나요?\nAI: AI: 당신은 현재 온라인 상에서 저와 대화하고 있습니다. 어떻게 도와드릴까요?"
# }
# [llm/start] [1:chain:LLMChain > 2:llm:ChatOpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: Progressively summarize the lines of conversation provided, adding onto the previous summary returning a new summary.\n\nEXAMPLE\nCurrent summary:\nThe human asks what the AI thinks of artificial intelligence. The AI thinks artificial intelligence is a force for good.\n\nNew lines of conversation:\nHuman: Why do you think artificial intelligence is a force for good?\nAI: Because artificial intelligence will help humans reach their full potential.\n\nNew summary:\nThe human asks what the AI thinks of artificial intelligence. The AI thinks artificial intelligence is a force for good because it will help humans reach their full potential.\nEND OF EXAMPLE\n\nCurrent summary:\nThe human greets the AI in Korean. The AI responds in Korean and asks how it can help.\n\nNew lines of conversation:\nHuman: 저는 어디에 있나요?\nAI: AI: 당신은 현재 온라인 상에서 저와 대화하고 있습니다. 어떻게 도와드릴까요?\n\nNew summary:"
#   ]
# }
# [llm/end] [1:chain:LLMChain > 2:llm:ChatOpenAI] s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "The human greets the AI in Korean and asks where they are. The AI responds in Korean, stating that they are currently conversing online and asks how it can help.",
#         "generation_info": {
#           "finish_reason": "stop"
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "The human greets the AI in Korean and asks where they are. The AI responds in Korean, stating that they are currently conversing online and asks how it can help.",
#             "additional_kwargs": {}
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": null,
#   "run": null
# }
# [chain/end] [1:chain:LLMChain] s] Exiting Chain run with output:
# {
#   "text": "The human greets the AI in Korean and asks where they are. The AI responds in Korean, stating that they are currently conversing online and asks how it can help."
# }
# 'AI: 당신은 현재 온라인 상에서 저와 대화하고 있습니다. 어떻게 도와드릴까요?'

# %%
memory.load_memory_variables({})
# Out:
# {'question_history': [HumanMessage(content='안녕하세요'),
#   AIMessage(content='안녕하세요! 무엇을 도와드릴까요?')]}
